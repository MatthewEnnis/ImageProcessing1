# %%
import cv2
from matplotlib import pyplot as plt

original = cv2.imread("wartime.jpg", 0)

originalvalues = original.ravel()

plt.subplot(1,2,1)
plt.hist(values,bins=256,range=[0,256]);

equalizedvalues = cv2.equalizeHist(values)

plt.subplot(1,2,2)
plt.hist(equalizedvalues,bins=256,range=[0,256]);

# %%
plt.subplot(1,2,1)
plt.imshow(original, cmap="gray")

equalized = cv2.equalizeHist(original)

plt.subplot(1,2,2)
plt.imshow(equalized, cmap="gray");
